# %%
# !pwd
# !ls -aF
# Out:
# /content/drive/MyDrive/GitHub/deep-learning-from-scratch-4
# ch01/		 ch06/	  .git/       policy_iter_state_10.gif	 policy_iter_state.gif
# ch04/		 ch07/	  .gitignore  policy_iter_state_12.gif	 policy_iter_step.gif
# ch04-debug.py	 ch08/	  images/     policy_iter_state_5.gif	 pytorch/
# ch04-exec.ipynb  ch09/	  LICENSE.md  policy_iter_state_8.gif	 README.md
# ch05/		 common/  notebooks/  policy_iter_state_bug.gif  .vscode/

# %%
# %cd drive/MyDrive/GitHub/
# !ls -aF
# Out:
# /content/drive/MyDrive/GitHub
# deep-learning-from-scratch-4/	   deep-learning-from-scratch-4-v1.0-dk0893/  git.ipynb
# deep-learning-from-scratch-4-org/  experiment/				      optuna-book/

# %%
# !git clone https://github.com/dk0893/deep-learning-from-scratch-4.git
# Out:
# Cloning into 'deep-learning-from-scratch-4'...
# remote: Enumerating objects: 413, done.
# remote: Counting objects: 100% (27/27), done.
# remote: Compressing objects: 100% (19/19), done.
# remote: Total 413 (delta 12), reused 13 (delta 8), pack-reused 386
# Receiving objects: 100% (413/413), 727.59 KiB | 6.06 MiB/s, done.
# Resolving deltas: 100% (234/234), done.

# %%
# %cd deep-learning-from-scratch-4/
# !ls -aF
# Out:
# /content/drive/MyDrive/GitHub/deep-learning-from-scratch-4
# ch01/		 ch06/	  .git/       policy_iter_state_10.gif	 policy_iter_state.gif
# ch04/		 ch07/	  .gitignore  policy_iter_state_12.gif	 policy_iter_step.gif
# ch04-debug.py	 ch08/	  images/     policy_iter_state_5.gif	 pytorch/
# ch04-exec.ipynb  ch09/	  LICENSE.md  policy_iter_state_8.gif	 README.md
# ch05/		 common/  notebooks/  policy_iter_state_bug.gif  .vscode/

# %%
# %cd drive/MyDrive/GitHub/deep-learning-from-scratch-4/
# !ls -aF
# Out:
# /content/drive/MyDrive/GitHub/deep-learning-from-scratch-4
# ch01/		 ch06/	  .git/       policy_iter_state_10.gif	policy_iter_step_bug.gif
# ch04/		 ch07/	  .gitignore  policy_iter_state_12.gif	pytorch/
# ch04-debug.py	 ch08/	  images/     policy_iter_state_5.gif	README.md
# ch04-exec.ipynb  ch09/	  LICENSE.md  policy_iter_state_8.gif	.vscode/
# ch05/		 common/  notebooks/  policy_iter_state.gif

# %%
# %cd ../
# !ls -aF
# Out:
# /content/drive/MyDrive
# 20070925.gmap  Blog/			      matplotlib_animation.py
# Backup/        deep-learning-from-scratch-4/  Repository/
# base.py        GitHub/			      無題のフォーム.gform

# %% [markdown]
# # master

# %% [markdown]
# ## ImageStoreクラスの動作確認
# * オリジナルの動作
# * --ope ani_step
# * --ope im_step
# * --ope im_state
# * --ope ani_state

# %%
# オリジナルの動作
# !python ch04/policy_iter.py
# Out:
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)
# Figure(640x480)

# %%
# アニメーション化
# !python ch04/policy_iter.py --ope ani_step --fpath policy_iter_step.gif
# Out:
# save animation: policy_iter_step.gif

# %%
# !ls -aF
# Out:
# ch01/  ch05/  ch07/  ch09/    exec.ipynb  .gitignore  notebooks/       pytorch/
# ch04/  ch06/  ch08/  common/  .git/	  LICENSE.md  policy_iter.gif  README.md

# %%
# 画像出力
# !python ch04/policy_iter.py --ope im_step
# !ls -aF
# Out:
# save image: images/policy_iter_step_0.png
# save image: images/policy_iter_step_1.png
# save image: images/policy_iter_step_2.png
# save image: images/policy_iter_step_3.png
# save image: images/policy_iter_step_4.png
# ch01/		 ch06/	  .git/       policy_iter_state_10.gif	 policy_iter_state.gif
# ch04/		 ch07/	  .gitignore  policy_iter_state_12.gif	 policy_iter_step.gif
# ch04-debug.py	 ch08/	  images/     policy_iter_state_5.gif	 pytorch/
# ch04-exec.ipynb  ch09/	  LICENSE.md  policy_iter_state_8.gif	 README.md
# ch05/		 common/  notebooks/  policy_iter_state_bug.gif  .vscode/

# %%
# 画像出力
# !python ch04/policy_iter.py --ope im_state
# !ls -aF
# Out:
# save image: images/policy_iter_step0_phase00_state_(0, 0).png
# save image: images/policy_iter_step0_phase00_state_(0, 1).png
# save image: images/policy_iter_step0_phase00_state_(0, 2).png
# save image: images/policy_iter_step0_phase00_state_(0, 3).png
# save image: images/policy_iter_step0_phase00_state_(1, 0).png
# save image: images/policy_iter_step0_phase00_state_(1, 1).png
# save image: images/policy_iter_step0_phase00_state_(1, 2).png
# save image: images/policy_iter_step0_phase00_state_(1, 3).png
# save image: images/policy_iter_step0_phase00_state_(2, 0).png
# save image: images/policy_iter_step0_phase00_state_(2, 1).png
# save image: images/policy_iter_step0_phase00_state_(2, 2).png
# save image: images/policy_iter_step0_phase00_state_(2, 3).png
# save image: images/policy_iter_step0_phase01_state_(0, 0).png
# save image: images/policy_iter_step0_phase01_state_(0, 1).png
# save image: images/policy_iter_step0_phase01_state_(0, 2).png
# ...

# %%
# アニメーション化
# !python ch04/policy_iter.py --ope ani_state --fpath policy_iter_state.gif
# Out:
# save animation: policy_iter_state.gif
# ImageStore.cnt=384

# %% [markdown]
# # v1.0-dk0893

# %%
# !pwd
# !ls -aF
# Out:
# /content
# ./  ../  .config/  drive/  sample_data/

# %%
# %cd drive/MyDrive/GitHub/
# !ls -aF
# Out:
# /content/drive/MyDrive/GitHub
# deep-learning-from-scratch-4/	   deep-learning-from-scratch-4-v1.0-dk0893/  git.ipynb
# deep-learning-from-scratch-4-org/  experiment/				      optuna-book/

# %%
# !git clone https://github.com/dk0893/deep-learning-from-scratch-4.git -b v1.0-dk0893 deep-learning-from-scratch-4-v1.0-dk0893
# Out:
# Cloning into 'deep-learning-from-scratch-4-v1.0-dk0893'...
# remote: Enumerating objects: 413, done.
# remote: Counting objects: 100% (27/27), done.
# remote: Compressing objects: 100% (19/19), done.
# remote: Total 413 (delta 12), reused 13 (delta 8), pack-reused 386
# Receiving objects: 100% (413/413), 727.59 KiB | 6.11 MiB/s, done.
# Resolving deltas: 100% (234/234), done.
# Note: switching to 'c5d97c442a764776f967e802d084c298f17aa9dd'.
#
# You are in 'detached HEAD' state. You can look around, make experimental
# changes and commit them, and you can discard any commits you make in this
# state without impacting any branches by switching back to a branch.
#
# If you want to create a new branch to retain commits you create, you may
# do so (now or later) by using -c with the switch command. Example:
#
#   git switch -c <new-branch-name>
#
# Or undo this operation with:
#
#   git switch -
#
# Turn off this advice by setting config variable advice.detachedHead to false

# %%
# %cd deep-learning-from-scratch-4-v1.0-dk0893/
# !ls -aF
# Out:
# /content/drive/MyDrive/GitHub/deep-learning-from-scratch-4-v1.0-dk0893
# ch01/  ch05/  ch07/  ch09/    .git/	  LICENSE.md  pytorch/
# ch04/  ch06/  ch08/  common/  .gitignore  notebooks/  README.md

# %%
# !python ch04/policy_iter.py --animation
# Out:
# Figure(640x480)

# %%
# !ls -aF
# Out:
# ch01/  ch05/  ch07/  ch09/    .git/	  LICENSE.md  policy_iter.gif  README.md
# ch04/  ch06/  ch08/  common/  .gitignore  notebooks/  pytorch/
